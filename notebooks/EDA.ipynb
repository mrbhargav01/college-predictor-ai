# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 📊 EduPath Pro - Exploratory Data Analysis\\n",
    "## College Admission & Placement Dataset Analysis\\n",
    "\\n",
    "This notebook performs comprehensive EDA on the college dataset including:\\n",
    "- Distribution Analysis\\n",
    "- Correlation Studies\\n",
    "- Trend Identification\\n",
    "- Outlier Detection\\n",
    "- Feature Engineering"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import plotly.express as px\n",
    "import plotly.graph_objects as go\n",
    "from plotly.subplots import make_subplots\n",
    "\n",
    "# Set style\n",
    "sns.set_style(\"whitegrid\")\n",
    "plt.rcParams['figure.figsize'] = (12, 8)\n",
    "\n",
    "# Load data\n",
    "df = pd.read_csv('../data/college_data.csv')\n",
    "print(f\"Dataset shape: {df.shape}\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Data Overview\n",
    "print(\"=== Data Types ===\")\n",
    "print(df.dtypes)\n",
    "print(\"\\n=== Missing Values ===\")\n",
    "print(df.isnull().sum())\n",
    "print(\"\\n=== Statistical Summary ===\")\n",
    "df.describe()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Distribution Plots\n",
    "fig, axes = plt.subplots(2, 3, figsize=(15, 10))\n",
    "\n",
    "sns.histplot(df['Cutoff_Percentile'], kde=True, ax=axes[0, 0])\n",
    "axes[0, 0].set_title('Cutoff Percentile Distribution')\n",
    "\n",
    "sns.histplot(df['Avg_Package_LPA'], kde=True, ax=axes[0, 1])\n",
    "axes[0, 1].set_title('Average Package Distribution')\n",
    "\n",
    "sns.histplot(df['Placement_Ratio'], kde=True, ax=axes[0, 2])\n",
    "axes[0, 2].set_title('Placement Ratio Distribution')\n",
    "\n",
    "sns.boxplot(y=df['Fees_Per_Year'], ax=axes[1, 0])\n",
    "axes[1, 0].set_title('Fees Distribution')\n",
    "\n",
    "sns.countplot(y=df['State'], order=df['State'].value_counts().head(10).index, ax=axes[1, 1])\n",
    "axes[1, 1].set_title('Top 10 States by College Count')\n",
    "\n",
    "sns.countplot(y=df['Course'], order=df['Course'].value_counts().head(8).index, ax=axes[1, 2])\n",
    "axes[1, 2].set_title('Top 8 Courses')\n",
    "\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Correlation Heatmap\n",
    "numeric_cols = ['Cutoff_Percentile', 'Avg_Package_LPA', 'Highest_Package_LPA',\n",
    "                'Fees_Per_Year', 'NIRF_Rank', 'Placement_Ratio', 'Campus_Rating',\n",
    "                'Faculty_Rating', 'Infrastructure_Rating', 'Research_Output',\n",
    "                'Industry_Connect', 'Alumni_Network', 'International_Students']\n",
    "\n",
    "corr_matrix = df[numeric_cols].corr()\n",
    "\n",
    "plt.figure(figsize=(12, 10))\n",
    "mask = np.triu(np.ones_like(corr_matrix, dtype=bool))\n",
    "sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f', cmap='RdBu_r',\n",
    "            center=0, square=True, linewidths=1)\n",
    "plt.title('Feature Correlation Matrix')\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Key Insights\n",
    "print(\"=== Top 5 Colleges by Avg Package ===\")\n",
    "top_package = df.nlargest(5, 'Avg_Package_LPA')[['College_Name', 'Avg_Package_LPA', 'Placement_Ratio']]\n",
    "print(top_package)\n",
    "\n",
    "print(\"\\n=== Top 5 Colleges by Placement Ratio ===\")\n",
    "top_placement = df.nlargest(5, 'Placement_Ratio')[['College_Name', 'Placement_Ratio', 'Avg_Package_LPA']]\n",
    "print(top_placement)\n",
    "\n",
    "print(\"\\n=== Average Metrics by Category ===\")\n",
    "print(df.groupby('Category')[['Avg_Package_LPA', 'Cutoff_Percentile', 'Placement_Ratio']].mean().round(2))\n",
    "\n",
    "print(\"\\n=== State-wise Performance ===\")\n",
    "state_perf = df.groupby('State').agg({\n",
    "    'Avg_Package_LPA': 'mean',\n",
    "    'Placement_Ratio': 'mean',\n",
    "    'NIRF_Rank': 'mean'\n",
    "}).round(2).sort_values('Avg_Package_LPA', ascending=False).head(10)\n",
    "print(state_perf)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
